# %%
import pandas as pd
import numpy as ny
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Read the CSV file into jupyter notebook

# %%
Iris_data = pd.read_csv('D:\DSA - ICT\Week 3 assignment-IRIS Dataset\iris.csv')

# %% [markdown]
# # Display the columns

# %%
Iris_data.head(150)
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # Display the column names

# %%
Iris_data.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %% [markdown]
# # Calculate the mean of all columns

# %%
Iris_data.mean(axis=0)
# Out:
# C:\Users\Dell\AppData\Local\Temp/ipykernel_18280/3136644515.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   Iris_data.mean(axis=0)
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %% [markdown]
# # Another method to calculate the mean

# %%
Iris_data.describe().loc["mean"]
# Out:
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# Name: mean, dtype: float64

# %% [markdown]
# # Check null values in columns

# %%
Iris_data.isna().any()
# Out:
# SL                False
# SW                False
# PL                False
# PW                False
# Classification    False
# dtype: bool

# %% [markdown]
# # Another method to check for null values

# %%
Iris_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   SL              150 non-null    float64
#  1   SW              150 non-null    float64
#  2   PL              150 non-null    float64
#  3   PW              150 non-null    float64
#  4   Classification  150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# # Visualisation of the Data

# %% [markdown]
# # Count of the dataset based on classification

# %%
plt.title("Count of the Classification",fontsize =12)
sns.countplot(Iris_data["Classification"])
plt.xlabel("Classification of the Species", fontsize =12)
plt.ylabel("Count of the classification", fontsize =12)
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'Count of the classification')

# %% [markdown]
# # Pairplot of the entire data set based on the classification

# %%
sns.pairplot(Iris_data,hue="Classification", markers=["o", "*", "^"])

# %% [markdown]
# # Box plot of the Data set - Each column parameter vs Classification

# %%
plt.figure(figsize=(10,10))

plt.subplot(2,2,1)
sns.boxplot(x="Classification",y="SL",data=Iris_data)
plt.subplot(2,2,2)
sns.boxplot(x="Classification",y="SW",data=Iris_data)
plt.subplot(2,2,3)
sns.boxplot(x="Classification",y="PL",data=Iris_data)
plt.subplot(2,2,4)
sns.boxplot(x="Classification",y="PW",data=Iris_data)

plt.tight_layout()

# %% [markdown]
# # Violin Plot of Dataset -Each column parameter with Classification

# %%
plt.figure(figsize=(10,10))

plt.subplot(2,2,1)
sns.violinplot(x="Classification",y="SL",data=Iris_data)
plt.subplot(2,2,2)
sns.violinplot(x="Classification",y="SW",data=Iris_data)
plt.subplot(2,2,3)
sns.violinplot(x="Classification",y="PL",data=Iris_data)
plt.subplot(2,2,4)
sns.violinplot(x="Classification",y="PW",data=Iris_data)
plt.tight_layout()

# %% [markdown]
# # Kernal Distribution plot of Data

# %%
Iris_data.plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# # Histogram of all columns dataset vs Frequency

# %%
plt.figure(figsize=(30,20))
Iris_data.hist(color="red", rwidth=0.9)
plt.tight_layout()

# %%
#Observation from above data visulisation 
#Count plot shows:
# Data of the all classification is same - 50 each
#Box plot shows :
#SL - Mean lowest for Iris Setosa & Highest for Iris Virginica
#SW - Mean lowest for Iris Versicolour & Highest for Iris Setosa
#PL - Mean lowest for Iris Setosa & Highest for Iris VIrginica
# PW - Mean lowest for Iris Setosa & Highest for Iris VIrginica
#Violin Plot shows:
#Enlarged areas shows maximum probability data
#Box plot and Violin plot show sentosa has smallest features except SW. 
#Box plot and Violin plot show there is some similarity in values for Versicolour and Virginica when SW is considered 
# Histogram shows the frequency range of all the parameters
